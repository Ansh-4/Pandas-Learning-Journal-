# %%
import pandas as pd

# %% [markdown]
# # Here CSV stands for Comma separated Values and it can be imported and then utilized by Pandas.
# I have taken a CSV file containing all original 150 Pokemons with all their stats

# %%
df = pd.read_csv(r"C:\Users\Ryuk\Jupyter\Notes\importing\pokemon-150.csv")
print(df)
# Out:
#       No        Name    Type1   Type2  Height  Weight  Legendary
# 0      1   Bulbasaur    Grass  Poison     0.7     6.9          0
# 1      2     Ivysaur    Grass  Poison     1.0    13.0          0
# 2      3    Venusaur    Grass  Poison     2.0   100.0          0
# 3      4  Charmander     Fire     NaN     0.6     8.5          0
# 4      5  Charmeleon     Fire     NaN     1.1    19.0          0
# ..   ...         ...      ...     ...     ...     ...        ...
# 145  146     Moltres     Fire  Flying     2.0    60.0          1
# 146  147     Dratini   Dragon     NaN     1.8     3.3          0
# 147  148   Dragonair   Dragon     NaN     4.0    16.5          0
# 148  149   Dragonite   Dragon  Flying     2.2   210.0          0
# 149  150      Mewtwo  Psychic     NaN     2.0   122.0          1
#
# [150 rows x 7 columns]

# %% [markdown]
# Here we have got the first five rows and last five rows in our output.

# %% [markdown]
# ## to print the entire dataframe (all the rows and columns) we will use string function.

# %%
print(df.to_string())
# Out:
#       No        Name     Type1     Type2  Height  Weight  Legendary
# 0      1   Bulbasaur     Grass    Poison     0.7     6.9          0
# 1      2     Ivysaur     Grass    Poison     1.0    13.0          0
# 2      3    Venusaur     Grass    Poison     2.0   100.0          0
# 3      4  Charmander      Fire       NaN     0.6     8.5          0
# 4      5  Charmeleon      Fire       NaN     1.1    19.0          0
# 5      6   Charizard      Fire    Flying     1.7    90.5          0
# 6      7    Squirtle     Water       NaN     0.5     9.0          0
# 7      8   Wartortle     Water       NaN     1.0    22.5          0
# 8      9   Blastoise     Water       NaN     1.6    85.5          0
# 9     10    Caterpie       Bug       NaN     0.3     2.9          0
# 10    11     Metapod       Bug       NaN     0.7     9.9          0
# 11    12  Butterfree       Bug    Flying     1.1    32.0          0
# 12    13      Weedle       Bug    Poison     0.3     3.2          0
# ...

# %% [markdown]
# # Json file (JavaScript Object Notation)
# ## to read a json file

# %%
df1 = pd.read_json(r"C:\Users\Ryuk\Jupyter\Notes\importing\models.json")
print(df1)
# Out:
#      value         title                                             models
# 0    ACURA         Acura  [{'value': 'CL_MODELS', 'title': 'CL Models (4...
# 1     ALFA    Alfa Romeo  [{'value': 'ALFA164', 'title': '164'}, {'value...
# 2      AMC           AMC  [{'value': 'AMCALLIAN', 'title': 'Alliance'}, ...
# 3    ASTON  Aston Martin  [{'value': 'DB7', 'title': 'DB7'}, {'value': '...
# 4     AUDI          Audi  [{'value': 'AUDI100', 'title': '100'}, {'value...
# ..     ...           ...                                                ...
# 66  TOYOTA        Toyota  [{'value': '4RUN', 'title': '4Runner'}, {'valu...
# 67     TRI       Triumph  [{'value': 'TR7', 'title': 'TR7'}, {'value': '...
# 68   VOLKS    Volkswagen  [{'value': 'BEETLE', 'title': 'Beetle'}, {'val...
# 69   VOLVO         Volvo  [{'value': '240', 'title': '240'}, {'value': '...
# 70    YUGO          Yugo  [{'value': 'GV', 'title': 'GV'}, {'value': 'GV...
#
# [71 rows x 3 columns]

# %% [markdown]
# # END
